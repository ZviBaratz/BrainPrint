# %% [markdown]
# # Questionnaire Scores Exploration

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from brainprint.recon_all.traits import TraitsExploration
from sklearn.cross_decomposition import CCA
from sklearn.cross_decomposition import PLSCanonical

# %%
te = TraitsExploration()
# Out:
# [2022-07-27 12:29:38,748] Successfully read 5160 recon-all execution results from /home/zvi/Projects/brainprint/data/results.csv.
# [2022-07-27 12:29:38,765] Successfully read 5160 recon-all execution configurations from /home/zvi/Projects/brainprint/data/configurations.csv.
# [2022-07-27 12:29:38,821] Successfully read 5160 scan research context and metadata from /home/zvi/Projects/brainprint/data/context.csv.
# [2022-07-27 12:29:39,217] Filtering 5160 recon-all results
# [2022-07-27 12:29:39,219] 2697/5160 recon-all results matching ['The Base (corrected)'] detected.
# [2022-07-27 12:29:39,222] 296/2697 recon-all results matching ['T2 + MPRAGE + 3T'] detected.
# [2022-07-27 12:29:39,227] Successfully selected 296 runs from 296 scans with all 1 recon-all execution configuration results.
# [2022-07-27 12:29:39,233] 203/5160 recon-all runs selected.

# %% [markdown]
# ## Target Matrix Pairplot

# %%
pairplot = te.plot_attributes_scatter_matrixes_scatter_matrix()
# Out:
# [2022-07-27 12:30:01,558] findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# [2022-07-27 12:30:01,612] findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# [2022-07-27 12:30:12,335] findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Decomposition

# %% [markdown]
# ### CCA

# %%
_ = te.plot_decomposition(CCA)

# %% [markdown]
# ### Canonical Partial Least Squares

# %%
_ = te.plot_decomposition(PLSCanonical)
